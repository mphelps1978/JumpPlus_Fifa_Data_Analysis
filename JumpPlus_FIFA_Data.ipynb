# %%
import pandas as pd

# %%
df = pd.read_csv('./data/players_20.csv')

# %%
pd.set_option('display.max_columns', None )
pd.set_option('display.max_rows', None )
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# Req. 1 - Show top 5 records
df.head()
# Out:
#    sofifa_id  \
# 0     158023
# 1      20801
# 2     190871
# 3     200389
# 4     183277
#
#                                                               player_url  \
# 0                https://sofifa.com/player/158023/lionel-messi/20/159586
# 1  https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/20/159586
# 2   https://sofifa.com/player/190871/neymar-da-silva-santos-jr/20/159586
# 3                   https://sofifa.com/player/200389/jan-oblak/20/159586
# 4                 https://sofifa.com/player/183277/eden-hazard/20/159586
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# ...

# %%
# Req. 2 - Display Each Column Name
list(df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
# Req. #3 - Show the number of rows and columns in the dataset
print("The Number of Rows: ", len(df))
print("The Number of Columns: ", len(df.columns))
# Out:
# The Number of Rows:  18278
# The Number of Columns:  104

# %%
# Req #4 Show the number of players and their countries
print(df.groupby(['nationality'])['nationality'].count())
# Out:
# nationality
# Afghanistan                2
# Albania                   43
# Algeria                   50
# Angola                    16
# Antigua & Barbuda          7
# Argentina                886
# Armenia                    8
# Australia                196
# Austria                  319
# Azerbaijan                 6
# Bahrain                    1
# Barbados                   1
# Belgium                  268
# Belize                     1
# Benin                     15
# Bermuda                    3
# Bolivia                   23
# Bosnia Herzegovina        66
# Brazil                   824
# Bulgaria                  41
# Burkina Faso              16
# Burundi                    4
# Cameroon                  78
# Canada                    61
# Cape Verde                20
# Central African Rep.       4
# Chad                       1
# Chile                    370
# China PR                 373
# Chinese Taipei             1
# Colombia                 591
# ...

# %%
# Req #5 - Show top 10 countries and their number of players
print(df.groupby(['nationality'])['nationality'].count().head(10).sort_values(ascending = False))
# Out:
# nationality
# Argentina            886
# Austria              319
# Australia            196
# Algeria               50
# Albania               43
# Angola                16
# Armenia                8
# Antigua & Barbuda      7
# Azerbaijan             6
# Afghanistan            2
# Name: nationality, dtype: int64

# %%
# Another way of doing 5, sorting the whole list, as opposed to just the top10
print(df.groupby(['nationality'])['nationality'].count().sort_values(ascending = False).head(10))
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
t5countries = df.groupby(['nationality'])['nationality'].count().sort_values(ascending = False).head(5)
